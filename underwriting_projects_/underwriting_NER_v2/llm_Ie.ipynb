# %%
import os
import pandas
import yaml
import re
import pandas as pd

# %%
import requests
import json


def qa_baichuan(input_):
    # 定义API的URL
    url = "https://api.baichuan-ai.com/v1/chat/completions"
    baichuan_key = "sk-4ce3bfe548d2bd5209aee1e19f72f4b8"

    # 定义请求头
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {baichuan_key}"  # 请确保你已经定义了API_KEY变量
    }

    # 定义请求体
    data = {
        "model": "Baichuan4",
        "messages":[
            {"role": "user",
        "content": input_}
        ],
        "temperature": 0.3,
        "stream": False
    }

    # 发送POST请求
    # response = requests.post(url, headers=headers, data=json.dumps(data))
    response = requests.post(url, headers=headers, json=data)


    # 检查响应状态码
    if response.status_code == 200:
        # 如果请求成功，打印响应内容
        # print(response.json())
        return response.json()["choices"][0]["message"]["content"]
    else:
        # 如果请求失败，打印错误信息
        print(f"Request failed with status code {response.status_code}")

# %%
home_path = "./report"
organ_names = [re.sub("_Report_Extraction_Config.yaml","",v) for v in os.listdir(home_path)]
for k in organ_names:
    print(k)
# Out:
# Kidney_Abdominal_BUS
# Attachments_Abdominal_BUS
# Holter_ECG
# Prostate_ULTRASOUND
# Thyroid_Ultrasound
# Resting_ECG
# Pancreas_Abdominal_BUS
# Liver_Abdominal_BUS
# Uterus_Abdominal_BUS
# Chest_Xray
# Echocardiogram
# Pulmonary_Function_Test
# Gallbladder_Abdominal_BUS
# Bladder_Urinary_Sys_ULTRASOUND
# Ureter_Urinary_Sys_ULTRASOUND
# Breast_Ultrasound
# Spleen_Abdominal_BUS
# Pulmonary_CT

# %%
from config import organ_zh_2_report
from config_out import organ_zh_2_ouput

organ_zh_2_en_map = {
    "肾脏腹部超声": "Kidney_Abdominal_BUS",
    "附件腹部超声": "Attachments_Abdominal_BUS",
    "霍尔特动态心电图": "Holter_ECG",
    "前列腺超声": "Prostate_ULTRASOUND",
    "甲状腺超声": "Thyroid_Ultrasound",
    "静息心电图": "Resting_ECG",
    "胰腺腹部超声": "Pancreas_Abdominal_BUS",
    "肝脏腹部超声": "Liver_Abdominal_BUS",
    "子宫腹部超声": "Uterus_Abdominal_BUS",
    "胸部X光": "Chest_Xray",
    "超声心动图": "Echocardiogram",
    "肺功能测试": "Pulmonary_Function_Test",
    "胆囊腹部超声": "Gallbladder_Abdominal_BUS",
    "膀胱泌尿系统超声": "Bladder_Urinary_Sys_ULTRASOUND",
    "输尿管泌尿系统超声": "Ureter_Urinary_Sys_ULTRASOUND",
    "乳腺超声": "Breast_Ultrasound",
    "脾脏腹部超声": "Spleen_Abdominal_BUS",
    "肺部CT": "Pulmonary_CT"
}


organ_en_2_zh_map = {
    "Kidney_Abdominal_BUS": "肾脏腹部超声",
    "Attachments_Abdominal_BUS": "附件腹部超声",
    "Holter_ECG": "霍尔特动态心电图",
    "Prostate_ULTRASOUND": "前列腺超声",
    "Thyroid_Ultrasound": "甲状腺超声",
    "Resting_ECG": "静息心电图",
    "Pancreas_Abdominal_BUS": "胰腺腹部超声",
    "Liver_Abdominal_BUS": "肝脏腹部超声",
    "Uterus_Abdominal_BUS": "子宫腹部超声",
    "Chest_Xray": "胸部X光",
    "Echocardiogram": "超声心动图",
    "Pulmonary_Function_Test": "肺功能测试",
    "Gallbladder_Abdominal_BUS": "胆囊腹部超声",
    "Bladder_Urinary_Sys_ULTRASOUND": "膀胱泌尿系统超声",
    "Ureter_Urinary_Sys_ULTRASOUND": "输尿管泌尿系统超声",
    "Breast_Ultrasound": "乳腺超声",
    "Spleen_Abdominal_BUS": "脾脏腹部超声",
    "Pulmonary_CT": "肺部CT"
}

data_map = {
"Kidney_Abdominal_BUS": "双肾",
"Attachments_Abdominal_BUS": "妇科",
"Holter_ECG": "运动心电图",
"Prostate_ULTRASOUND": "前列腺",
"Thyroid_Ultrasound": "甲状腺",
"Resting_ECG": "静息心电图",
"Pancreas_Abdominal_BUS": "胰腺",
"Liver_Abdominal_BUS": "肝脏",
"Uterus_Abdominal_BUS": "妇科",
"Chest_Xray": "胸片",
"Echocardiogram": "超声心电图",
"Pulmonary_Function_Test": "肺功能",
"Gallbladder_Abdominal_BUS": "胆囊",
"Bladder_Urinary_Sys_ULTRASOUND": "泌尿超声",
"Ureter_Urinary_Sys_ULTRASOUND": "泌尿超声",
"Breast_Ultrasound": "乳腺",
"Spleen_Abdominal_BUS": "脾脏",
"Pulmonary_CT": "肺CT"
}


out_key_list = ["patient_basic_information","comparative_study","report_details","attachments_and_additional_info",""]
pattern_tail = "_Report_Extraction_Config.yaml"
home_path = "./report"
print(organ_zh_2_en_map.keys())
# Out:
# dict_keys(['肾脏腹部超声', '附件腹部超声', '霍尔特动态心电图', '前列腺超声', '甲状腺超声', '静息心电图', '胰腺腹部超声', '肝脏腹部超声', '子宫腹部超声', '胸部X光', '超声心动图', '肺功能测试', '胆囊腹部超声', '膀胱泌尿系统超声', '输尿管泌尿系统超声', '乳腺超声', '脾脏腹部超声', '肺部CT'])

# %%
# report_type = "甲状腺超声"
# report_type = "肺部CT"
# report_type = "肾脏腹部超声"
# report_type = "肝脏腹部超声"
# report_type = "胆囊腹部超声"
# report_type = "胰腺腹部超声"
# report_type = "脾脏腹部超声"
# report_type = "子宫腹部超声"
# report_type = "乳腺超声"
# report_type = "膀胱泌尿系统超声"
report_type = "超声心动图"


 #字段
config_field = organ_zh_2_report.get(report_type,"")

#输出格式
ouput = organ_zh_2_ouput.get(report_type,"")

en_organ_type = organ_zh_2_en_map.get(report_type)
print("器官英文名字:",en_organ_type)

sheet_name = data_map.get(en_organ_type,"")
print(f"sheet name:{sheet_name}")

#case数据读取
print("case数据读取")
file_name = "./NLP回归测试1219_result.xlsx"
df_data = pd.read_excel(file_name,sheet_name=sheet_name,keep_default_na=False)

print("select input")
#select one case
input = df_data["description"].tolist()[2]
print(input)
# Out:
# 器官英文名字: Echocardiogram
# sheet name:超声心电图
# case数据读取
# select input
# 心脏各房室腔内径正常。房室间隔连续完整。各组瓣膜形态、回声未见异常。 室壁运动分析：左室各段心肌厚度、动度及回声未见异常。 左室收缩功能：LVEF:63%。 CDFI:三尖瓣探及微少量反流信号+未见明显异常

# %%
prompt = """
您是一个医疗数据提取助手，专门用于解析{report_type}报告。您的任务是从给定的报告文本中提取以下结构化信息，并将其填写在指定的字典字段值中。请确保信息的准确性和完整性，特别是在提取结节描述和诊断意见部分。

需要提取的信息和结构样式：
    {config_field}

**注意**: 如果报告中没有提供某些字段的数据，请用 `NULL`字符串 或 `未描述` 填充。输出应保持 `python` 字典结构，并以 `python` 代码块格式返回。

**输出示例**：
```python
{ouput}
```
    
报告文本：
{input}

注意事项：
    1、返回的结果字典中不需要带注释
    2、无法从报告文本中找到的信息就填“NULL”
    3、报告文本中没有的信息，不可以从字段值信息解释中提取
    
"""

input_prompt = prompt.format(report_type=report_type,config_field=config_field,ouput=ouput,input=input)
print(input_prompt)
# Out:
# 您是一个医疗数据提取助手，专门用于解析超声心动图报告。您的任务是从给定的报告文本中提取以下结构化信息，并将其填写在指定的字典字段值中。请确保信息的准确性和完整性，特别是在提取结节描述和诊断意见部分。
#
# 需要提取的信息和结构样式：
#
# report_information:
#   report_id: "string"                    # 报告唯一标识
#   patient_id: "string"                   # 患者唯一标识
#   exam_date: "YYYY-MM-DD"                # 检查日期，格式：YYYY-MM-DD
#   exam_location: "string"                # 检查部位，如“超声心动图”
#   conclusion: "string"                   # 结论
#   recommendations: "string"              # 建议（如适用）
#
#
# echocardiogram_findings:
#   chambers:
#     left_atrium:
#       size_cm: "float"                    # 左心房大小，单位：厘米
#       size_unit: "string"                 # 单位，通常为“cm”
#       volume_ml: "float"                   # 左心房容积，单位：毫升
#       volume_unit: "string"                # 单位，通常为“ml”
#       wall_thickness_mm: "float"           # 左心房壁厚，单位：毫米
#       wall_thickness_unit: "string"        # 单位，通常为“mm”
#       function: "string"                   # 功能描述，如“正常”、“扩大”等
#
#     left_ventricle:
#       size_cm: "float"                    # 左心室大小，单位：厘米
#       size_unit: "string"                 # 单位，通常为“cm”
#       volume_ml: "float"                   # 左心室容积，单位：毫升
#       volume_unit: "string"                # 单位，通常为“ml”
#       wall_thickness_mm: "float"           # 左心室壁厚，单位：毫米
#       wall_thickness_unit: "string"        # 单位，通常为“mm”
#       ejection_fraction_percent: "float"    # 射血分数，单位：%
#       fractional_shortening_percent: "float" # 短缩分数，单位：%
#       function: "string"                   # 功能描述，如“正常”、“收缩功能减退”等
#
#     right_atrium:
#       size_cm: "float"                    # 右心房大小，单位：厘米
#       size_unit: "string"                 # 单位，通常为“cm”
#       volume_ml: "float"                   # 右心房容积，单位：毫升
#       volume_unit: "string"                # 单位，通常为“ml”
#       wall_thickness_mm: "float"           # 右心房壁厚，单位：毫米
#       wall_thickness_unit: "string"        # 单位，通常为“mm”
#       function: "string"                   # 功能描述，如“正常”、“扩大”等
#
#     right_ventricle:
#       size_cm: "float"                    # 右心室大小，单位：厘米
#       size_unit: "string"                 # 单位，通常为“cm”
#       volume_ml: "float"                   # 右心室容积，单位：毫升
#       volume_unit: "string"                # 单位，通常为“ml”
#       wall_thickness_mm: "float"           # 右心室壁厚，单位：毫米
#       wall_thickness_unit: "string"        # 单位，通常为“mm”
#       function: "string"                   # 功能描述，如“正常”、“收缩功能减退”等
#
#   valves:
#     mitral_valve:
#       morphology: "string"                  # 形态，如“正常”、“瓣膜增厚”等
#       regurgitation_grade: "integer"        # 返流分级，如1-4级
#       stenosis_grade: "integer"             # 狭窄分级，如1-4级
#       associated_features: "string"         # 相关特征，如“钙化”、“脱垂”等
#
#     aortic_valve:
#       morphology: "string"                  # 形态，如“正常”、“瓣膜增厚”等
#       regurgitation_grade: "integer"        # 返流分级，如1-4级
#       stenosis_grade: "integer"             # 狭窄分级，如1-4级
#       associated_features: "string"         # 相关特征，如“钙化”、“脱垂”等
#
#     tricuspid_valve:
#       morphology: "string"                  # 形态，如“正常”、“瓣膜增厚”等
#       regurgitation_grade: "integer"        # 返流分级，如1-4级
#       stenosis_grade: "integer"             # 狭窄分级，如1-4级
#       associated_features: "string"         # 相关特征，如“钙化”、“脱垂”等
#
#     pulmonary_valve:
#       morphology: "string"                  # 形态，如“正常”、“瓣膜增厚”等
#       regurgitation_grade: "integer"        # 返流分级，如1-4级
#       stenosis_grade: "integer"             # 狭窄分级，如1-4级
#       associated_features: "string"         # 相关特征，如“钙化”、“脱垂”等
#
#   pericardium:
#     effusion_present: "boolean"             # 是否存在心包积液
#     effusion_volume_ml: "float"             # 心包积液量，单位：毫升
#     effusion_characteristics: "string"      # 心包积液特征，如“无”、“少量”、“中量”、“大量”
#     constrictive_pericarditis: "boolean"    # 是否存在限制性心包炎
#
#   wall_motion:
#     abnormalities_present: "boolean"        # 是否存在壁运动异常
#     regions_with_abnormal_motion: "list"    # 存在壁运动异常的区域，如“前壁”、“侧壁”等
#     description: "string"                   # 描述，如“运动减弱”、“运动缺失”等
#
#   doppler_findings:
#     mitral_inflow:
#       e_velocity_cm_s: "float"              # E波速度，单位：cm/s
#       a_velocity_cm_s: "float"              # A波速度，单位：cm/s
#       e_a_ratio: "float"                     # E/A比值
#       deceleration_time_ms: "float"          # E波减速时间，单位：毫秒
#
#     tricuspid_inflow:
#       e_velocity_cm_s: "float"              # E波速度，单位：cm/s
#       a_velocity_cm_s: "float"              # A波速度，单位：cm/s
#       e_a_ratio: "float"                     # E/A比值
#       deceleration_time_ms: "float"          # E波减速时间，单位：毫秒
#
#     aortic_outflow:
#       velocity_cm_s: "float"                # 最高速度，单位：cm/s
#       pressure_gradient_mmHg: "float"        # 压力梯度，单位：mmHg
#
#     pulmonic_outflow:
#       velocity_cm_s: "float"                # 最高速度，单位：cm/s
#       pressure_gradient_mmHg: "float"        # 压力梯度，单位：mmHg
#
# quantitative_metrics:
#   ejection_fraction_percent: "float"          # 射血分数，单位：%
#   fractional_shortening_percent: "float"      # 短缩分数，单位：%
#   left_atrium_volume_ml: "float"               # 左心房容积，单位：毫升
#   left_ventricle_volume_ml: "float"            # 左心室容积，单位：毫升
#   right_atrium_volume_ml: "float"              # 右心房容积，单位：毫升
#   right_ventricle_volume_ml: "float"           # 右心室容积，单位：毫升
#   mitral_valve_area_cm2: "float"               # 二尖瓣面积，单位：cm²
#   aortic_valve_area_cm2: "float"               # 主动脉瓣面积，单位：cm²
#   tricuspid_valve_area_cm2: "float"            # 三尖瓣面积，单位：cm²
#   pulmonary_valve_area_cm2: "float"            # 肺动脉瓣面积，单位：cm²
#
# diagnostic_opinion:
#   accurate_diagnosis: "string"                  # 准确的诊断名称
#
#
# **注意**: 如果报告中没有提供某些字段的数据，请用 `NULL`字符串 或 `未描述` 填充。输出应保持 `python` 字典结构，并以 `python` 代码块格式返回。
#
# **输出示例**：
# ```python
#
# ```
#
# 报告文本：
# 心脏各房室腔内径正常。房室间隔连续完整。各组瓣膜形态、回声未见异常。 室壁运动分析：左室各段心肌厚度、动度及回声未见异常。 左室收缩功能：LVEF:63%。 CDFI:三尖瓣探及微少量反流信号+未见明显异常
#
# 注意事项：
#     1、返回的结果字典中不需要带注释
#     2、无法从报告文本中找到的信息就填“NULL”
#     3、报告文本中没有的信息，不可以从字段值信息解释中提取

# %%
gen_result_bc = qa_baichuan(input_prompt)

# %%
print(gen_result_bc)
# Out:
# ```python
# {
#     'report_information': {
#         'report_id': '123456',
#         'patient_id': '987654',
#         'exam_date': '2024-12-25',
#         'exam_location': '甲状腺',
#         'conclusion': '甲状腺右侧叶下极低回声结节，TI-RADS分级（IVa级，可疑？）',
#         'ultrasound_mode': '彩色多普勒'
#     },
#     'organ_extraction': {
#         'Organ_thyroid': {
#             'description': '甲状腺大小尚可，形态规则，右侧叶下极可见大小约5.2x6.6mm的低回声结节，边界清，形态不规则，纵横比大于1，其内可见大小约1.6x1.3mm的强回声，周边可见血流信号显示，余腺体回声均匀',
#             'is_normal': False,
#             'size_cm': 5.2,
#             'echotexture': '均匀',
#             'echogenicity': '低回声',
#             'margins': '清晰',
#             'echogenic_foci': '强回声',
#             'calcifications': '有钙化',
#             'echo_condition': '未见异常',
#             'shape': '不规则',
#             'morphology': '形态不规则',
#             'size_status': '正常',
#             'blood_flow': '周边可见血流信号',
#             'enhancement': '无',
#             'posterior_echo': '无异常',
#             'elasticity': '未描述',
#             'capsule': '未描述',
#             'surgical_history': '未描述'
#         },
#         'Organ_larynx': '未描述',
#         'Organ_trachea': '未描述',
#         'Organ_cervical_lymph_nodes': '未探及异常增大淋巴结'
#     },
#     'space_occupying_lesions': [
#         {
#             'lesion_id': '1',
#             'lesion_type': '结节',
#             'lesion_subtype': '实性',
#             'location': '右叶下极',
#             'size_long_axis_cm': 6.6,
#             'size_short_axis_cm': 5.2,
#             'composition': '实性',
#             'echogenicity': '低回声',
#             'margins': '清晰',
#             'calcifications': '有钙化',
#             'vascularity': '无',
#             'shape': '不规则',
#             'morphology': '形态不规则',
#             'aspect_ratio': '>',
#             'number': 1,
#             'suspected_diagnosis': '可疑结节',
#             'surrounding_tissue': '周围无异常',
#             'additional_features': '无囊性变'
#         }
#     ],
#     'quantitative_metrics': {
#         'thyroid_volume_ml': 15.0,
#         'nodule_count': 1,
#         'largest_nodule_size_cm': 6.6,
#         'vascular_index': 0.5
#     },
#     'lymph_nodes': {
#         'lymph_node_condition': '未见异常增大淋巴结',
#         'activity': '未描述',
#         'cortex_medulla': '未描述',
#         'gate': '未描述'
#     },
#     'diagnostic_opinion': {
#         'accurate_diagnosis': '甲状腺右侧叶下极低回声结节，TI-RADS分级（IVa级，可疑？）'
#     }
# }
# ```

# %% [markdown]
# # case reading

# %%
file_name = "./NLP回归测试1219_result.xlsx"
df_ = pd.ExcelFile(file_name)
sheet_names_list = df_.sheet_names
print(sheet_names_list)
df_ct = pd.read_excel(file_name,sheet_name="甲状腺",keep_default_na=False)
# Out:
# ['总览', '甲状腺', '乳腺', '肝脏', '胆囊', '胰腺', '脾脏', '双肾', '妇科', '泌尿超声', '前列腺', '肺CT', '静息心电图', 'TCT', '运动心电图', '超声心电图', '胸片', '肺功能', '心率', '淋巴结', '头颅CT', '乙肝五项', '尿镜检', '视力']

# %%
sheet_name = data_map.get(en_organ_type,"")
df_data = pd.read_excel(file_name,sheet_name=sheet_name,keep_default_na=False)

# %% [markdown]
# ## output处理

# %%
def match_struct_data(gen_result_bc):
    pattern = r"```python(.*?)```"
    matches = re.findall(pattern, gen_result_bc, re.DOTALL)
    if matches:
        code_content = matches[0].strip()
        code_dict = eval(code_content)
        print("type:",type(code_dict))
        print(code_dict)
    else:
        print("not match")
        code_dict = {}
    return code_dict

# %%
report_path = os.path.join(home_path,en_organ_type+pattern_tail)
with open(report_path, 'r') as file:
    config = yaml.safe_load(file)

# 现在 config 是一个字典，包含了 YAML 文件中定义的所有结构
